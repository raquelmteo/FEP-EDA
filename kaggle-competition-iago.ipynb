# %% [markdown]
# ## Business Understanding

# %% [markdown]
# **Identifiers & Metadata**
#
# application_id: A unique identifier for each individual loan application.
#
# customer_id: A unique identifier for each customer. A single customer may have multiple applications.
#
# application_date: The date on which the loan application was submitted.
#
# data_batch_id: An identifier for the data processing batch this record belongs to.
#
# **Loan Characteristics**
#
# loan_amount_requested: The principal amount of the loan requested by the applicant.
#
# loan_amount_usd: The requested loan amount converted to US Dollars for standardization.
#
# loan_tenure_months: The duration of the loan repayment period in months.
#
# interest_rate_offered: The annual interest rate offered for the loan.
#
# purpose_of_loan: The stated reason for seeking the loan.
#
# loan_type_*: A set of binary columns indicating the specific type of loan product.
#
# **Applicant Financial Profile**
#
# employment_status: The applicant's current employment situation.
#
# monthly_income: The applicant's stated gross monthly income.
#
# yearly_income: The applicant's stated gross annual income.
#
# annual_bonus: The applicant's declared annual bonus amount.
#
# cibil_score: A credit score (e.g., from CIBIL) representing the applicant's creditworthiness and history. Higher scores indicate better credit health.
#
# existing_emis_monthly: The total amount of Equated Monthly Installments (EMIs) the applicant is currently paying for other existing loans.
#
# debt_to_income_ratio: This ratio helps assess an applicant's ability to manage monthly payments.
#
# credit_utilization_ratio: The ratio of the applicant's outstanding credit card debt to their total credit card limit.
#
# **Applicant Demographics & Personal Information**
#
# applicant_age: The age of the applicant in years at the time of application.
#
# gender_*: A set of one-hot encoded binary columns representing the applicant's gender.
#
# property_ownership_status: The applicant's housing situation.
#
# residential_address: The applicant's provided residential address (likely anonymized or generalized).
#
# number_of_dependents: The number of people financially dependent on the applicant.
#
# **Target Variable**
#
# fraud_flag: This is the key target variable for prediction. It's a binary indicator where 1 signifies a fraudulent application and 0 signifies a legitimate application.

# %%
# basic libraries
import pandas as pd

# data preparation libraries
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from imblearn.over_sampling import SMOTE

# prediction models libraries
from sklearn.metrics import classification_report
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn import linear_model
from sklearn.neighbors import KNeighborsClassifier
from sklearn import tree

# %% [markdown]
# ## Modelling

# %% [markdown]
# ### Data Treatment

# %%
df = pd.read_csv('train.csv')
df = df.drop(columns=['Unnamed: 0', 'data_batch_id']) ##removing first column, that looks just an random id
# keep only distinct rows, removing duplicated ones
df=df.drop_duplicates()

# drop dates
df = df.drop(columns='application_date')

# removing unwanted object features
categCols = ['purpose_of_loan', 'employment_status', 'property_ownership_status']
df[categCols] = df[categCols].astype('category')
df = df.select_dtypes(exclude='object')

# capitalizing category features
for column in categCols:
    df[column]=df[column].str.capitalize()
    df[column]=df[column].str.strip()

# removing untrustable dummy columns
dummyDrop = [col for col in df.columns if 'loan_type' in col]
df = df.drop(columns=dummyDrop)

# %% [markdown]
# ### Outliers Removal

# %%
# removing outliers by the loan tenure months
q1 = df['loan_tenure_months'].quantile(0.25)
q3 = df['loan_tenure_months'].quantile(0.75)
iqr = q3-q1
upperBound = q3 + iqr*1.5

# removing outliers
df = df[df['loan_tenure_months']<=upperBound]

# %% [markdown]
# ### Imputation

# %% [markdown]
# #### Gender

# %%
def gender_code(row):
    if row['gender_Male'] == 1:
        return 1
    elif row['gender_Other'] == 1:
        return 0
    else:
        None #columns as neither male or other will be treated as unkown

df['gender_code'] = df.apply(gender_code, axis=1)

# %%
## gender imputation through KNN

# defining known and unknown gender
dfKnown = df[df['gender_code'].notna()]
dfUnknown = df[df['gender_code'].isna()]

# defining train columns
colsTrain = ['debt_to_income_ratio', 'applicant_age', 'yearly_income', 'annual_bonus']

## using the known data to train the model

# defining the train dataset
xTrain = dfKnown[colsTrain]
xTest = dfUnknown[colsTrain]
yTrain = dfKnown['gender_code']

# standardizing the known and unknown selected attributes
scaler = StandardScaler()
xTrainScaled = scaler.fit_transform(xTrain)
xTestScaled = scaler.transform(xTest)

# training the model
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(xTrainScaled, yTrain)

# replacing the missing values by the KNN prediction
df.loc[df['gender_code'].isna(), 'gender_code'] = knn.predict(xTestScaled)

# %%
# recreating the gender label, where "0" is man and "1" is woman
genderDrop = ['gender_Male', 'gender_Other']
df = df.drop(columns=genderDrop)
df = df.rename(columns={'gender_code': 'gender_male'})

# 0: woman ; 1: man
df['gender_male'].value_counts()
# Out:
# gender_male
# 0.0    20096
# 1.0    19541
# Name: count, dtype: int64

# %% [markdown]
# #### Monthly Income

# %%
# inputting monthly income
df['monthly_income'] = df['monthly_income'].fillna(df['yearly_income']/12)

# %% [markdown]
# #### Number of Dependents

# %%
## gender imputation through KNN

# defining known and unknown gender
dfKnown = df[df['number_of_dependents'].notna()]
dfUnknown = df[df['number_of_dependents'].isna()]

# defining train columns
colsTrain = ['debt_to_income_ratio', 'applicant_age', 'yearly_income', 'annual_bonus']

## using the known data to train the model

# defining the train dataset
xTrain = dfKnown[colsTrain]
xTest = dfUnknown[colsTrain]
yTrain = dfKnown['number_of_dependents']

# standardizing the known and unknown selected attributes
scaler = StandardScaler()
xTrainScaled = scaler.fit_transform(xTrain)
xTestScaled = scaler.transform(xTest)

# training the model
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(xTrainScaled, yTrain)

# replacing the missing values by the KNN prediction
df.loc[df['number_of_dependents'].isna(), 'number_of_dependents'] = knn.predict(xTestScaled)

# %% [markdown]
# #### Dummying

# %%
# transforming categorical features into dummy ones, removing one of the categories to avoid colinearility
df = pd.get_dummies(df, columns=categCols, drop_first=True, dtype=int)

# %% [markdown]
# ## Prediction

# %% [markdown]
# ### Preparing dataset for the models

# %%
# setting target variable
y = df['fraud_flag']

# setting feature columns
xCols = [col for col in df.columns if col != 'fraud_flag']
x = df[xCols]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)

# setting dummy columns
dummyCols = [col for col in xCols if any(sub in col for sub in categCols) or col == 'gender_male']
notDummyCols = [col for col in xCols if col not in dummyCols] 

# scaling feature columns but dummy ones
scaler = StandardScaler()
x_train_scaled = pd.DataFrame(
    scaler.fit_transform(x_train[notDummyCols]), #both train the model and scales
    columns=notDummyCols, 
    index=x_train.index)
x_test_scaled = pd.DataFrame(
    scaler.transform(x_test[notDummyCols]),  #apply the scaled model in the test data
    columns=notDummyCols, 
    index=x_test.index)

# concatenating the dummy cols int he scaled numeric features
x_train_final = pd.concat([x_train_scaled, x_train[dummyCols]], axis=1)
x_test_final = pd.concat([x_test_scaled, x_test[dummyCols]], axis=1)

# both train and test
x_scaled = pd.concat([x_train_final, x_test_final], axis=0)

# smoted scaled 
smote = SMOTE(sampling_strategy='minority')
x_train_SMOTE, y_smote = smote.fit_resample(x_train_final, y_train) #smotes train only

# %% [markdown]
# ### Logistic Regression

# %% [markdown]
# #### Stepwising for Logistic Regression

# %%
# creating model
log_reg_model = linear_model.LogisticRegression(max_iter=1000, random_state=42, class_weight='balanced')

# defining the stepwise model
sfs_log_reg = SequentialFeatureSelector(
    log_reg_model,
    scoring='f1',
    cv=None
)

# applying the stepwise model, which should be done only on the training data
selected_features = sfs_log_reg.fit(x_train_final, y_train)

# selecting the stepwised features
x_train_stepwised = x_train_final[selected_features.get_feature_names_out()]
x_test_stepwised = x_test_final[selected_features.get_feature_names_out()]

# %% [markdown]
# #### Logistic Regression Application (Simple)

# %%
log_reg_model.fit(x_train_final, y_train)

# prediction
y_pred = log_reg_model.predict(x_test_final)

print("Confusion Matrix:")
print(pd.crosstab(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# storing results in dict
results = dict()

results['Logistic Regression'] = classification_report(y_test, y_pred, output_dict=True)
# Out:
# Confusion Matrix:
# col_0          0     1
# fraud_flag
# 0           3468  3390
# 1            528   542
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.51      0.64      6858
#            1       0.14      0.51      0.22      1070
#
#     accuracy                           0.51      7928
#    macro avg       0.50      0.51      0.43      7928
# weighted avg       0.77      0.51      0.58      7928

# %% [markdown]
# #### Logistic Regresion w/ Stepwise

# %%
# training stepwised model
log_reg_model.fit(x_train_stepwised, y_train)

# prediction
y_pred = log_reg_model.predict(x_test_stepwised)

print("Confusion Matrix:")
print(pd.crosstab(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# storing results in dict
results['Logistic Regression w/ Stepwise'] = classification_report(y_test, y_pred, output_dict=True)
# Out:
# Confusion Matrix:
# col_0          0     1
# fraud_flag
# 0           2493  4365
# 1            399   671
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.36      0.51      6858
#            1       0.13      0.63      0.22      1070
#
#     accuracy                           0.40      7928
#    macro avg       0.50      0.50      0.37      7928
# weighted avg       0.76      0.40      0.47      7928

# %% [markdown]
# #### Logistic Regression w/ Stepwise and SMOTE resampling

# %%
# stepwising after SMOTE
selected_features_SMOTE = sfs_log_reg.fit(x_train_SMOTE, y_smote) #select features after SMOTE
x_stepwised_SMOTE = x_train_SMOTE[selected_features_SMOTE.get_feature_names_out()]

# training stepwised and smoted model
log_reg_model.fit(x_stepwised_SMOTE, y_smote)

# selecting the stepwise columns for the test sample
x_test_stepwised = x_test_final[x_stepwised_SMOTE.columns]

# the smoted data should be used only for training, not for tests
y_pred = log_reg_model.predict(x_test_stepwised)

print("Confusion Matrix:")
print(pd.crosstab(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# storing results in dict
results['Logistic Regression w/ Stepwise and SMOTE'] = classification_report(y_test, y_pred, output_dict=True)
# Out:
# Confusion Matrix:
# col_0          0     1
# fraud_flag
# 0           1962  4896
# 1            303   767
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.29      0.43      6858
#            1       0.14      0.72      0.23      1070
#
#     accuracy                           0.34      7928
#    macro avg       0.50      0.50      0.33      7928
# weighted avg       0.77      0.34      0.40      7928

# %% [markdown]
# #### KNN (Simple)

# %%
# training KNN to predict the flags (before it was for the number of dependents)
n_neighbors = 3
knn_model = KNeighborsClassifier(n_neighbors=n_neighbors, weights='distance')
knn_model.fit(x_train_final, y_train)

# predicting with KNN
y_pred = knn_model.predict(x_test_final)

print("Confusion Matrix:")
print(pd.crosstab(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# storing results in dict
results[f'KNN ({n_neighbors})'] = classification_report(y_test, y_pred, output_dict=True)
# Out:
# Confusion Matrix:
# col_0          0    1
# fraud_flag
# 0           6502  356
# 1           1018   52
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.90      6858
#            1       0.13      0.05      0.07      1070
#
#     accuracy                           0.83      7928
#    macro avg       0.50      0.50      0.49      7928
# weighted avg       0.77      0.83      0.79      7928

# %% [markdown]
# #### KNN w/ Stepwise

# %%
# defining the stepwise model
sfs_knn = SequentialFeatureSelector(
    knn_model,
    scoring='f1',
    cv=None
)

# applying the stepwise model
selected_features = sfs_knn.fit(x_train_final, y_train)

# selecting the stepwised features
x_train_stepwised = x_train_final[selected_features.get_feature_names_out()]
x_test_stepwised = x_test_final[selected_features.get_feature_names_out()]

# training knn with the stepwised columns
knn_model.fit(x_train_stepwised, y_train)

# predicting with KNN
y_pred = knn_model.predict(x_test_stepwised)

print("Confusion Matrix:")
print(pd.crosstab(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# storing results in dict
results[f'KNN ({n_neighbors}) w/ Stepwise'] = classification_report(y_test, y_pred, output_dict=True)
# Out:
# Confusion Matrix:
# col_0          0    1
# fraud_flag
# 0           6323  535
# 1            993   77
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.92      0.89      6858
#            1       0.13      0.07      0.09      1070
#
#     accuracy                           0.81      7928
#    macro avg       0.50      0.50      0.49      7928
# weighted avg       0.76      0.81      0.78      7928

# %% [markdown]
# #### KNN w/ Stepwise and SMOTE

# %%
# stepwising after SMOTE
selected_features_SMOTE = sfs_knn.fit(x_train_SMOTE, y_smote) #select features after SMOTE
x_stepwised_SMOTE = x_train_SMOTE[selected_features_SMOTE.get_feature_names_out()]

# selecting the stepwise columns for the test sample
x_test_stepwised = x_test_final[x_stepwised_SMOTE.columns]

# training stepwised and smoted model
knn_model.fit(x_stepwised_SMOTE, y_smote)

# predicting with KNN
y_pred = knn_model.predict(x_test_stepwised)

print("Confusion Matrix:")
print(pd.crosstab(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# storing results in dict
results[f'KNN ({n_neighbors}) w/ Stepwise and SMOTE'] = classification_report(y_test, y_pred, output_dict=True)
# Out:
# Confusion Matrix:
# col_0          0     1
# fraud_flag
# 0           4760  2098
# 1            742   328
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.69      0.77      6858
#            1       0.14      0.31      0.19      1070
#
#     accuracy                           0.64      7928
#    macro avg       0.50      0.50      0.48      7928
# weighted avg       0.77      0.64      0.69      7928

# %% [markdown]
# #### Decision Tree

# %%
# loading the decision tree model
dtree_model = tree.DecisionTreeClassifier(random_state=42)

# training the decision tree model
dtree_model.fit(x_train_final, y_train)

# predicting
y_pred = dtree_model.predict(x_test)

print("Confusion Matrix:")
print(pd.crosstab(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# storing results in dict
results['Decision Tree'] = classification_report(y_test, y_pred, output_dict=True)
# Out:
# Confusion Matrix:
# col_0          0     1
# fraud_flag
# 0           5696  1162
# 1            908   162
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.85      6858
#            1       0.12      0.15      0.14      1070
#
#     accuracy                           0.74      7928
#    macro avg       0.49      0.49      0.49      7928
# weighted avg       0.76      0.74      0.75      7928

# %% [markdown]
# #### Decision Tree w/ Grid Search

# %%
# setting the initial hyperparameters
param_grid = {
    'max_depth': [30, 35, 35],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# loading the grid search decision tree model
dtree_model = tree.DecisionTreeClassifier(random_state=42)

# grid search parameters setting
grid_search = GridSearchCV(
    estimator=dtree_model,
    param_grid=param_grid,
    cv=5,
    scoring='f1',
    n_jobs=-1,
    verbose=1,
    error_score='raise'
)

# applying the grid search
grid_search.fit(x_train_final, y_train)
best_dtree_model = grid_search.best_estimator_

# prediction
y_pred = best_dtree_model.predict(x_test_final)

print("Confusion Matrix:")
print(pd.crosstab(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# storing results in dict
results['Decision Tree w/ GridSearch'] = classification_report(y_test, y_pred, output_dict=True)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Confusion Matrix:
# col_0          0     1
# fraud_flag
# 0           5757  1101
# 1            901   169
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.84      0.85      6858
#            1       0.13      0.16      0.14      1070
#
#     accuracy                           0.75      7928
#    macro avg       0.50      0.50      0.50      7928
# weighted avg       0.77      0.75      0.76      7928

# %%
print(
    'max_depth', best_dtree_model.max_depth, '\n',
    'min_samples_splt', best_dtree_model.min_samples_split, '\n',
    'min_samples_leaf', best_dtree_model.min_samples_leaf)
# Out:
# max_depth 35
#  min_samples_splt 2
#  min_samples_leaf 1

# %% [markdown]
# #### Decision Tree w/ Grid Search and SMOTE

# %%
# setting the initial hyperparameters
param_grid = {
    'max_depth': [30, 35, 35],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# loading the grid search decision tree model
dtree_model = tree.DecisionTreeClassifier(random_state=42)

# grid search parameters setting
grid_search = GridSearchCV(
    estimator=dtree_model,
    param_grid=param_grid,
    cv=5,
    scoring='f1',
    n_jobs=-1,
    verbose=1,
)

# applying the grid search
grid_search.fit(x_train_SMOTE, y_smote)
best_dtree_model = grid_search.best_estimator_

# prediction
y_pred = best_dtree_model.predict(x_test_final)

print("Confusion Matrix:")
print(pd.crosstab(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# storing results in dict
results['Decision Tree w/ GridSearch and SMOTE'] = classification_report(y_test, y_pred, output_dict=True)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Confusion Matrix:
# col_0          0     1
# fraud_flag
# 0           5821  1037
# 1            894   176
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86      6858
#            1       0.15      0.16      0.15      1070
#
#     accuracy                           0.76      7928
#    macro avg       0.51      0.51      0.51      7928
# weighted avg       0.77      0.76      0.76      7928

# %%
print(
    'max_depth', best_dtree_model.max_depth, '\n',
    'min_samples_splt', best_dtree_model.min_samples_split, '\n',
    'min_samples_leaf', best_dtree_model.min_samples_leaf)
# Out:
# max_depth 30
#  min_samples_splt 5
#  min_samples_leaf 2

# %%
# all models
models = list(results.keys())

all_rows = []

for model in models:
    rep = results[model]  # classification_report dict

    row = {}
    row['model'] = model

    # classes 0 and 1
    for label in ['0', '1']:
        for metric in ['precision', 'recall', 'f1-score']:
            row[f'{label}_{metric}'] = rep[label][metric]

    # accuracy
    row['accuracy'] = rep['accuracy']

    # macro avg
    for metric in ['precision', 'recall', 'f1-score']:
        row[f'macro_{metric}'] = rep['macro avg'][metric]

    # weighted avg
    for metric in ['precision', 'recall', 'f1-score']:
        row[f'weighted_{metric}'] = rep['weighted avg'][metric]

    all_rows.append(row)

df_results = pd.DataFrame(all_rows)

df_results
# Out:
#                                        model  0_precision  0_recall  \
# 0                        Logistic Regression     0.867868  0.505687
# 1            Logistic Regression w/ Stepwise     0.862033  0.363517
# 2  Logistic Regression w/ Stepwise and SMOTE     0.866225  0.286089
# 3                                    KNN (3)     0.864628  0.948090
# 4                        KNN (3) w/ Stepwise     0.864270  0.921989
# 5              KNN (3) w/ Stepwise and SMOTE     0.865140  0.694080
# 6                              Decision Tree     0.862508  0.830563
# 7                Decision Tree w/ GridSearch     0.864674  0.839458
# 8      Decision Tree w/ GridSearch and SMOTE     0.866865  0.848790
#
#    0_f1-score  1_precision  1_recall  1_f1-score  accuracy  macro_precision  \
# 0    0.639027     0.137843  0.506542    0.216713  0.505802         0.502856
# 1    0.511385     0.133241  0.627103    0.219784  0.399092         0.497637
# 2    0.430122     0.135441  0.716822    0.227833  0.344223         0.500833
# 3    0.904437     0.127451  0.048598    0.070365  0.826690         0.496039
# 4    0.892197     0.125817  0.071963    0.091558  0.807265         0.495044
# 5    0.770227     0.135202  0.306542    0.187643  0.641776         0.500171
# 6    0.846234     0.122356  0.151402    0.135338  0.738900         0.492432
# 7    0.851879     0.133071  0.157944    0.144444  0.747477         0.498872
# 8    0.857732     0.145095  0.164486    0.154183  0.756433         0.505980
#
#    macro_recall  macro_f1-score  weighted_precision  weighted_recall  \
# 0      0.506114        0.427870            0.769340         0.505802
# 1      0.495310        0.365584            0.763672         0.399092
# 2      0.501456        0.328977            0.767595         0.344223
# 3      0.498344        0.487401            0.765135         0.826690
# 4      0.496976        0.491877            0.764605         0.807265
# 5      0.500311        0.478935            0.766624         0.641776
# 6      0.490982        0.490786            0.762613         0.738900
# 7      0.498701        0.498162            0.765933         0.747477
# 8      0.506638        0.505958            0.769452         0.756433
#
#    weighted_f1-score
# 0           0.582030
# 1           0.472029
# 2           0.402820
# 3           0.791867
# 4           0.784139
# 5           0.691598
# 6           0.750288
# 7           0.756401
# 8           0.762778
